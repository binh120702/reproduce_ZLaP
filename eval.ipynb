# %%
from zlap import run_experiment 

datasets = [
    "dtd", "eurosat", "fgvca", "flowers", "food101",
    "pets", "sun397", "cars", "caltech101", "cifa10", 
    "cifar100", "cub", "ucf101"
]

setups = ["transductive", "inductive", "sparse-inductive"]
clf_types = ["text"]
backbones = ["RN50_openai", "ViT-B-16_openai"]  # or add more if needed

results = []

for dataset in datasets:
    for setup in setups:
        for clf_type in clf_types:
            for backbone in backbones:
                try:
                    res = run_experiment(
                        dataset=dataset,
                        backbone=backbone,
                        setup=setup,
                        clf_type=clf_type,
                        k=5,
                        gamma=5.0,
                        alpha=0.3
                    )
                    print(res)
                    results.append({**res, "setup": setup, "clf_type": clf_type, "backbone": backbone})
                except Exception as e:
                    print(f"Failed on {dataset}-{setup}-{clf_type}: {e}")
# Out:
# {'dataset': 'dtd', 'accuracy': 41.903073286052006}
# {'dataset': 'dtd', 'accuracy': 45.981087470449175}
# {'dataset': 'dtd', 'accuracy': 42.78959810874704}
# {'dataset': 'dtd', 'accuracy': 48.58156028368794}
# {'dataset': 'dtd', 'accuracy': 43.14420803782506}
# {'dataset': 'dtd', 'accuracy': 49.11347517730496}
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'eurosat', 'accuracy': 35.54320987654321}
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'eurosat', 'accuracy': 57.67901234567901}
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'eurosat', 'accuracy': 31.85185185185185}
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'eurosat', 'accuracy': 55.617283950617285}
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'eurosat', 'accuracy': 38.839506172839506}
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'eurosat', 'accuracy': 58.20987654320987}
# {'dataset': 'fgvca', 'accuracy': 17.821782178217823}
# {'dataset': 'fgvca', 'accuracy': 26.282628262826282}
# {'dataset': 'fgvca', 'accuracy': 17.37173717371737}
# {'dataset': 'fgvca', 'accuracy': 25.442544254425442}
# {'dataset': 'fgvca', 'accuracy': 17.941794179417943}
# {'dataset': 'fgvca', 'accuracy': 25.832583258325833}
# {'dataset': 'flowers', 'accuracy': 65.93585058871295}
# {'dataset': 'flowers', 'accuracy': 67.8846934632562}
# {'dataset': 'flowers', 'accuracy': 69.26512383272431}
# {'dataset': 'flowers', 'accuracy': 73.48761672756801}
# {'dataset': 'flowers', 'accuracy': 68.7779131140885}
# {'dataset': 'flowers', 'accuracy': 72.63499796995534}
# {'dataset': 'food101', 'accuracy': 78.83498349834983}
# {'dataset': 'food101', 'accuracy': 87.15511551155116}
# {'dataset': 'food101', 'accuracy': 77.87458745874588}
# {'dataset': 'food101', 'accuracy': 86.92409240924093}
# {'dataset': 'food101', 'accuracy': 78.25742574257426}
# {'dataset': 'food101', 'accuracy': 87.34323432343234}
# {'dataset': 'pets', 'accuracy': 83.94657944944126}
# {'dataset': 'pets', 'accuracy': 87.89860997547015}
# {'dataset': 'pets', 'accuracy': 80.32161351866993}
# {'dataset': 'pets', 'accuracy': 87.13545925320251}
# {'dataset': 'pets', 'accuracy': 77.6778413736713}
# {'dataset': 'pets', 'accuracy': 86.29054238212046}
# {'dataset': 'sun397', 'accuracy': 63.29974811083123}
# {'dataset': 'sun397', 'accuracy': 67.77329974811083}
# {'dataset': 'sun397', 'accuracy': 61.83375314861461}
# {'dataset': 'sun397', 'accuracy': 67.43576826196474}
# {'dataset': 'sun397', 'accuracy': 61.14861460957179}
# {'dataset': 'sun397', 'accuracy': 67.17380352644837}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cars', 'accuracy': 57.83582089552239}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cars', 'accuracy': 66.80348258706468}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cars', 'accuracy': 56.417910447761194}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cars', 'accuracy': 65.63432835820896}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cars', 'accuracy': 55.82089552238806}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cars', 'accuracy': 66.09452736318408}
# {'dataset': 'caltech101', 'accuracy': 89.61460446247465}
# {'dataset': 'caltech101', 'accuracy': 91.84584178498986}
# {'dataset': 'caltech101', 'accuracy': 86.89655172413794}
# {'dataset': 'caltech101', 'accuracy': 93.06288032454361}
# {'dataset': 'caltech101', 'accuracy': 86.32860040567951}
# {'dataset': 'caltech101', 'accuracy': 92.12981744421907}
# No train features! Inductive setting will not be possible!
# No val features!!!
# No test features! Using val features as test!
# Failed on cifa10-transductive-text: No val features either!
# No train features! Inductive setting will not be possible!
# No val features!!!
# No test features! Using val features as test!
# Failed on cifa10-transductive-text: No val features either!
# No train features! Inductive setting will not be possible!
# No val features!!!
# No test features! Using val features as test!
# Failed on cifa10-inductive-text: No val features either!
# No train features! Inductive setting will not be possible!
# No val features!!!
# No test features! Using val features as test!
# Failed on cifa10-inductive-text: No val features either!
# No train features! Inductive setting will not be possible!
# No val features!!!
# No test features! Using val features as test!
# Failed on cifa10-sparse-inductive-text: No val features either!
# No train features! Inductive setting will not be possible!
# No val features!!!
# No test features! Using val features as test!
# Failed on cifa10-sparse-inductive-text: No val features either!
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cifar100', 'accuracy': 47.93}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cifar100', 'accuracy': 70.85}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cifar100', 'accuracy': 45.95}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cifar100', 'accuracy': 71.03}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cifar100', 'accuracy': 47.99}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cifar100', 'accuracy': 72.04}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cub', 'accuracy': 52.140144977563}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cub', 'accuracy': 58.18087676907145}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cub', 'accuracy': 49.689333793579564}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cub', 'accuracy': 59.371763893683124}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cub', 'accuracy': 51.12185018985157}
# No test features! Using val features as test!
# No InMaP classifer learned on test, so using the one trained on val instead!
# No InMaP classifer learned on test, so using the one trained on val instead!
# {'dataset': 'cub', 'accuracy': 59.07835692095271}
# {'dataset': 'ucf101', 'accuracy': 65.92651334919375}
# {'dataset': 'ucf101', 'accuracy': 73.80385937086967}
# {'dataset': 'ucf101', 'accuracy': 62.807295796986516}
# {'dataset': 'ucf101', 'accuracy': 71.45122918318795}
# {'dataset': 'ucf101', 'accuracy': 64.23473433782712}
# {'dataset': 'ucf101', 'accuracy': 72.24425059476606}

# %%
for result in results:
    print(result)
# Out:
# {'dataset': 'dtd', 'accuracy': 41.903073286052006, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'dtd', 'accuracy': 45.981087470449175, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'dtd', 'accuracy': 42.78959810874704, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'dtd', 'accuracy': 48.58156028368794, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'dtd', 'accuracy': 43.14420803782506, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'dtd', 'accuracy': 49.11347517730496, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'eurosat', 'accuracy': 35.54320987654321, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'eurosat', 'accuracy': 57.67901234567901, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'eurosat', 'accuracy': 31.85185185185185, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'eurosat', 'accuracy': 55.617283950617285, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'eurosat', 'accuracy': 38.839506172839506, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'eurosat', 'accuracy': 58.20987654320987, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'fgvca', 'accuracy': 17.821782178217823, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'fgvca', 'accuracy': 26.282628262826282, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'fgvca', 'accuracy': 17.37173717371737, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'fgvca', 'accuracy': 25.442544254425442, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'fgvca', 'accuracy': 17.941794179417943, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'fgvca', 'accuracy': 25.832583258325833, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'flowers', 'accuracy': 65.93585058871295, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'flowers', 'accuracy': 67.8846934632562, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'flowers', 'accuracy': 69.26512383272431, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'flowers', 'accuracy': 73.48761672756801, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'flowers', 'accuracy': 68.7779131140885, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'flowers', 'accuracy': 72.63499796995534, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'food101', 'accuracy': 78.83498349834983, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'food101', 'accuracy': 87.15511551155116, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'food101', 'accuracy': 77.87458745874588, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'food101', 'accuracy': 86.92409240924093, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'food101', 'accuracy': 78.25742574257426, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'food101', 'accuracy': 87.34323432343234, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'pets', 'accuracy': 83.94657944944126, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'pets', 'accuracy': 87.89860997547015, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'pets', 'accuracy': 80.32161351866993, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'pets', 'accuracy': 87.13545925320251, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'pets', 'accuracy': 77.6778413736713, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'pets', 'accuracy': 86.29054238212046, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'sun397', 'accuracy': 63.29974811083123, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'sun397', 'accuracy': 67.77329974811083, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'sun397', 'accuracy': 61.83375314861461, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'sun397', 'accuracy': 67.43576826196474, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'sun397', 'accuracy': 61.14861460957179, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'sun397', 'accuracy': 67.17380352644837, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'cars', 'accuracy': 57.83582089552239, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'cars', 'accuracy': 66.80348258706468, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'cars', 'accuracy': 56.417910447761194, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'cars', 'accuracy': 65.63432835820896, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'cars', 'accuracy': 55.82089552238806, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'cars', 'accuracy': 66.09452736318408, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'caltech101', 'accuracy': 89.61460446247465, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'caltech101', 'accuracy': 91.84584178498986, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'caltech101', 'accuracy': 86.89655172413794, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'caltech101', 'accuracy': 93.06288032454361, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'caltech101', 'accuracy': 86.32860040567951, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'caltech101', 'accuracy': 92.12981744421907, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'cifar100', 'accuracy': 47.93, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'cifar100', 'accuracy': 70.85, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'cifar100', 'accuracy': 45.95, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'cifar100', 'accuracy': 71.03, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'cifar100', 'accuracy': 47.99, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'cifar100', 'accuracy': 72.04, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'cub', 'accuracy': 52.140144977563, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'cub', 'accuracy': 58.18087676907145, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'cub', 'accuracy': 49.689333793579564, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'cub', 'accuracy': 59.371763893683124, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'cub', 'accuracy': 51.12185018985157, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'cub', 'accuracy': 59.07835692095271, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'ucf101', 'accuracy': 65.92651334919375, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'ucf101', 'accuracy': 73.80385937086967, 'setup': 'transductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'ucf101', 'accuracy': 62.807295796986516, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'ucf101', 'accuracy': 71.45122918318795, 'setup': 'inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}
# {'dataset': 'ucf101', 'accuracy': 64.23473433782712, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'RN50_openai'}
# {'dataset': 'ucf101', 'accuracy': 72.24425059476606, 'setup': 'sparse-inductive', 'clf_type': 'text', 'backbone': 'ViT-B-16_openai'}

# %%
import json 

with open("reproduced_results.txt", "w") as f:
    f.write(json.dumps(results, indent=4))
